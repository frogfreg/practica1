# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'USvideos.csv'
df = pd.read_csv(path)
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
# video_id                  40949 non-null object
# trending_date             40949 non-null object
# title                     40949 non-null object
# channel_title             40949 non-null object
# category_id               40949 non-null int64
# publish_time              40949 non-null object
# tags                      40949 non-null object
# views                     40949 non-null int64
# likes                     40949 non-null int64
# dislikes                  40949 non-null int64
# comment_count             40949 non-null int64
# thumbnail_link            40949 non-null object
# comments_disabled         40949 non-null bool
# ratings_disabled          40949 non-null bool
# video_error_or_removed    40949 non-null bool
# description               40379 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
df.shape
# Out:
# (40949, 16)

# %%
df.shape[0]
# Out:
# 40949

# %%
df.shape[1]
# Out:
# 16

# %%
df.columns.values.tolist()
# Out:
# ['video_id',
#  'trending_date',
#  'title',
#  'channel_title',
#  'category_id',
#  'publish_time',
#  'tags',
#  'views',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'thumbnail_link',
#  'comments_disabled',
#  'ratings_disabled',
#  'video_error_or_removed',
#  'description']

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['description']

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
df.loc[[0]]
# Out:
#       video_id trending_date                               title  \
# 0  2kyS6SvSYSE      17.14.11  WE WANT TO TALK ABOUT OUR MARRIAGE
#
#   channel_title  category_id              publish_time             tags  \
# 0  CaseyNeistat           22  2017-11-13T17:13:01.000Z  SHANtell martin
#
#     views  likes  dislikes  comment_count  \
# 0  748374  57527      2966          15954
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
#
#    ratings_disabled  video_error_or_removed  \
# 0             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...

# %%
df.loc[30:33]
# Out:
#        video_id trending_date  \
# 30  U0hAC8O7RoI      17.14.11
# 31  CBVGjS_EJok      17.14.11
# 32  n1WpP7iowLc      17.14.11
# 33  hz7ukDjuq4w      17.14.11
#
#                                                 title channel_title  \
# 30  I TOOK THE $3,000,000 LAMBO TO CARMAX! They of...   hp_overload
# 31        Amazon Christmas Advert 2017 - Toys & Games  Amazon.co.uk
# 32         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 33                    What's Inside a Detectives Car?    officer401
#
#     category_id              publish_time  \
# 30            2  2017-11-13T01:43:12.000Z
# 31           24  2017-11-06T17:52:50.000Z
# 32           10  2017-11-10T17:00:03.000Z
# 33           24  2017-11-12T23:41:37.000Z
#
#                                                  tags     views   likes  \
# 30  carmax|"lamborghini miura"|"miura carmax"|"lam...     98378    4035
# 31  Amazon|"Amazon Christmas"|"Amazon Xmas"|"Chris...     26000     119
# ...

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#       video_id trending_date  \
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
#
#                                                title          channel_title  \
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
#
#    category_id              publish_time  \
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
# 5           28  2017-11-13T19:07:23.000Z
#
# ...

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#        video_id trending_date  \
# 0   2kyS6SvSYSE      17.14.11
# 5   gHZ1Qz0KiKM      17.14.11
# 6   39idVpFF7NQ      17.14.11
# 7   nc99ccSXST0      17.14.11
# 8   jr9QtXwC9vc      17.14.11
# 9   TUmyygCMMGA      17.14.11
# 10  9wRQljFNDW8      17.14.11
# 11  VifQlJit6A0      17.14.11
# 12  5E4ZBSInqUU      17.14.11
# 13  GgVmn66oK_A      17.14.11
#
#                                                 title        channel_title  \
# 0                  WE WANT TO TALK ABOUT OUR MARRIAGE         CaseyNeistat
# 5                               2 Weeks with iPhone X             iJustine
# 6           Roy Moore & Jeff Sessions Cold Open - SNL  Saturday Night Live
# 7                 5 Ice Cream Gadgets put to the Test   CrazyRussianHacker
# 8   The Greatest Showman | Official Trailer 2 [HD]...     20th Century Fox
# 9   Why the rise of the robots won’t mean the end ...                  Vox
# 10  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...                  NFL
# ...

# %%
df[100:].head()
# Out:
#         video_id trending_date  \
# 100  fCTKDn3Q8xQ      17.14.11
# 101  DIU3xPdhCBI      17.14.11
# 102  wnwF1FHybDQ      17.14.11
# 103  9oFP-pOMNwE      17.14.11
# 104  pz95u3UVpaM      17.14.11
#
#                                                  title  \
# 100            Idiot's Guide to Japanese Squat Toilets
# 101  Sam Smith surprises brides at their wedding! (...
# 102  Mark Wahlberg's Kids Use Him for His Celeb Con...
# 103  H&M Holiday 2017 starring Nicki Minaj – offici...
# 104  Camila Cabello - Havana (Vertical Video) ft. Y...
#
#                    channel_title  category_id              publish_time  \
# 100               Rachel and Jun           22  2017-11-09T11:24:14.000Z
# 101                    BBC Music           10  2017-11-09T22:26:10.000Z
# 102  Late Night with Seth Meyers           23  2017-11-10T11:00:04.000Z
# 103                          H&M           24  2017-11-09T08:01:40.000Z
# 104            CamilaCabelloVEVO           10  2017-11-10T05:01:00.000Z
#
# ...

# %%
df.views.values
# Out:
# array([  748374,  2418783,  3191434, ...,  1066451,  5660813, 10306119],
#       dtype=int64)

# %%
df['views'].values
# Out:
# array([  748374,  2418783,  3191434, ...,  1066451,  5660813, 10306119],
#       dtype=int64)

# %%
df.views.unique()
# Out:
# array([  748374,  2418783,  3191434, ...,  1066451,  5660813, 10306119],
#       dtype=int64)

# %%
df.views.value_counts()
# Out:
# 235077     3
# 427242     3
# 8493       3
# 168135     3
# 241387     3
#           ..
# 82493      1
# 2050620    1
# 487995     1
# 500734     1
# 268291     1
# Name: views, Length: 40478, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          video_id  trending_date  title  channel_title  category_id  \
# count       40949          40949  40949          40949        40949
# size        40949          40949  40949          40949        40949
# nunique      6351            205   6455           2207           16
#
#          publish_time   tags  views  likes  dislikes  comment_count  \
# count           40949  40949  40949  40949     40949          40949
# size            40949  40949  40949  40949     40949          40949
# nunique          6269   6055  40478  29850      8516          13773
#
#          thumbnail_link  comments_disabled  ratings_disabled  \
# count             40949              40949             40949
# size              40949              40949             40949
# nunique            6352                  2                 2
#
#          video_error_or_removed  description
# count                     40949        40371
# size                      40949        40949
# ...

# %%
df.groupby('views').agg(['count', 'size', 'nunique']).stack()
# Out:
#                    video_id  trending_date  title  channel_title  category_id  \
# views
# 549       count           1              1      1              1            1
#           size            1              1      1              1            1
#           nunique         1              1      1              1            1
# 554       count           1              1      1              1            1
#           size            1              1      1              1            1
# ...                     ...            ...    ...            ...          ...
# 220490543 size            1              1      1              1            1
#           nunique         1              1      1              1            1
# 225211923 count           1              1      1              1            1
#           size            1              1      1              1            1
#           nunique         1              1      1              1            1
#
# ...

# %%
df.groupby('views').agg(['count', 'size', 'nunique'])
# Out:
#           video_id              trending_date              title               \
#              count size nunique         count size nunique count size nunique
# views
# 549              1    1       1             1    1       1     1    1       1
# 554              1    1       1             1    1       1     1    1       1
# 559              1    1       1             1    1       1     1    1       1
# 658              1    1       1             1    1       1     1    1       1
# 687              1    1       1             1    1       1     1    1       1
# ...            ...  ...     ...           ...  ...     ...   ...  ...     ...
# 205643016        1    1       1             1    1       1     1    1       1
# 210338856        1    1       1             1    1       1     1    1       1
# 217750076        1    1       1             1    1       1     1    1       1
# 220490543        1    1       1             1    1       1     1    1       1
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#           video_id trending_date  \
# 22745  00RpZZThSAs      18.09.03
# 33187  1Aoc-cd9eYs      18.07.05
# 12833  _zu53yAoTJE      18.19.01
# 25194  EL1wN_ihL_E      18.22.03
# 7802   cMD63TwzB1o      17.23.12
#
#                                                    title        channel_title  \
# 22745         How Good is McDonald's New Szechuan Sauce?   TheReportOfTheWeek
# 33187  Cobra Kai Ep 2 - Strike First - The Karate Kid...            Cobra Kai
# 12833      U2 - Get Out Of Your Own Way (Official Video)               U2VEVO
# 25194                      Jurassic Park Auditions - SNL  Saturday Night Live
# 7802                  SZA - The Weekend (Official Video)              SZAVEVO
#
#        category_id              publish_time  \
# 22745           24  2018-02-26T16:44:55.000Z
# 33187           24  2018-05-02T16:02:35.000Z
# 12833           10  2018-01-18T16:00:02.000Z
# 25194           24  2018-03-18T11:16:05.000Z
# 7802            10  2017-12-22T05:00:01.000Z
#
# ...

# %%
df.shape
# Out:
# (40949, 16)

# %%
df_sample.shape
# Out:
# (2047, 16)

# %%
df_dropped = df.dropna(subset=['channel_title'])
df_dropped.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df_dropped.shape
# Out:
# (40949, 16)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df_copy.shape
# Out:
# (40949, 16)

# %%
df_dropped['views'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['views'].mean()
# Out:
# 2360784.6382573447

# %%
df_copy['views'].fillna(value=np.round(df['views'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          video_id  trending_date  title  channel_title  category_id  \
# count       40949          40949  40949          40949        40949
# size        40949          40949  40949          40949        40949
# nunique      6351            205   6455           2207           16
#
#          publish_time   tags  views  likes  dislikes  comment_count  \
# count           40949  40949  40949  40949     40949          40949
# size            40949  40949  40949  40949     40949          40949
# nunique          6269   6055  40478  29850      8516          13773
#
#          thumbnail_link  comments_disabled  ratings_disabled  \
# count             40949              40949             40949
# size              40949              40949             40949
# nunique            6352                  2                 2
#
#          video_error_or_removed  description
# count                     40949        40371
# size                      40949        40949
# ...

# %%
list(df['channel_title'].unique())
# Out:
# ['CaseyNeistat',
#  'LastWeekTonight',
#  'Rudy Mancuso',
#  'Good Mythical Morning',
#  'nigahiga',
#  'iJustine',
#  'Saturday Night Live',
#  'CrazyRussianHacker',
#  '20th Century Fox',
#  'Vox',
#  'NFL',
#  'amc',
#  'marshmello',
#  'NowThis World',
#  'The king of DIY',
#  'BostonDynamics',
#  'Cracked',
#  'TED-Ed',
#  'PeterSripol',
#  'SciShow',
#  'Life Noggin',
#  'Tested',
#  'Tom Scott',
#  'Refinery29',
#  'Gus Johnson',
#  'HellthyJunkFood',
#  'Numberphile',
#  'JerryRigEverything',
#  'Cleveland Cavaliers on cleveland.com',
#  'FaeryInLoveInc',
#  'hp_overload',
#  'Amazon.co.uk',
#  'EminemVEVO',
#  'officer401',
#  'Emirates',
#  'Nobrand',
#  'Screen Junkies',
#  'Hunter Hayes',
#  'Niki and Gabi',
#  'Nickelback',
#  'U2VEVO',
#  'BBC News',
#  'Ben Rohrbach',
#  'MatthewSantoro',
#  'Shawn Johnson East',
#  'dope2111',
#  'People are Awesome',
#  'NBA Highlights · YouTube',
#  'D3sports.com',
#  'FBE',
#  'Simply Nailogical',
#  'CBS Sunday Morning',
# ...

# %%
keys = list(df['channel_title'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'CaseyNeistat': 1,
#  'LastWeekTonight': 2,
#  'Rudy Mancuso': 3,
#  'Good Mythical Morning': 4,
#  'nigahiga': 5,
#  'iJustine': 6,
#  'Saturday Night Live': 7}

# %%
df['channel_title'].map(act)
df_copy.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df_copy['views'].mean()
# Out:
# 2360784.6382573447

# %%
df_copy['views'][df_copy['channel_title'] == 6]
# Out:
# Series([], Name: views, dtype: int64)

# %%
df_copy.groupby(["channel_title", "views", "title"]).count()
# Out:
#                                                                                    video_id  \
# channel_title          views   title
# 12 News                85643   Bill Gates bought land in Arizona to build tech...         1
#                        92327   Bill Gates bought land in Arizona to build tech...         1
# 1MILLION Dance Studio  210802  This is me - The Greatest Showman OST / Jun Liu...         1
#                        307249  This is me - The Greatest Showman OST / Jun Liu...         1
#                        352080  This is me - The Greatest Showman OST / Jun Liu...         1
# ...                                                                                     ...
# 영국남자 Korean Englishman 890350  한국 치맥 왕중왕전: 외국인 입맛에 제일 잘 맞는 한국 치킨은?!                       1
#                        1019288 한국 치맥 왕중왕전: 외국인 입맛에 제일 잘 맞는 한국 치킨은?!                       1
#                        1103504 한국 치맥 왕중왕전: 외국인 입맛에 제일 잘 맞는 한국 치킨은?!                       1
# ...

# %%
df_copy.channel_title
# Out:
# 0                    CaseyNeistat
# 1                 LastWeekTonight
# 2                    Rudy Mancuso
# 3           Good Mythical Morning
# 4                        nigahiga
#                    ...
# 40944               AaronsAnimals
# 40945                    zefrank1
# 40946                  Brad Mondo
# 40947    How It Should Have Ended
# 40948                Call of Duty
# Name: channel_title, Length: 40949, dtype: object

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#           video_id trending_date  \
# 22745  00RpZZThSAs      18.09.03
# 33187  1Aoc-cd9eYs      18.07.05
# 12833  _zu53yAoTJE      18.19.01
# 25194  EL1wN_ihL_E      18.22.03
# 7802   cMD63TwzB1o      17.23.12
#
#                                                    title        channel_title  \
# 22745         How Good is McDonald's New Szechuan Sauce?   TheReportOfTheWeek
# 33187  Cobra Kai Ep 2 - Strike First - The Karate Kid...            Cobra Kai
# 12833      U2 - Get Out Of Your Own Way (Official Video)               U2VEVO
# 25194                      Jurassic Park Auditions - SNL  Saturday Night Live
# 7802                  SZA - The Weekend (Official Video)              SZAVEVO
#
#        category_id              publish_time  \
# 22745           24  2018-02-26T16:44:55.000Z
# 33187           24  2018-05-02T16:02:35.000Z
# 12833           10  2018-01-18T16:00:02.000Z
# 25194           24  2018-03-18T11:16:05.000Z
# 7802            10  2017-12-22T05:00:01.000Z
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
df_sample.plot(kind='scatter',x='views',y='likes')

# %%
plt.hist(df_sample['views'])
plt.xlabel('views')
plt.ylabel('Frequency')
plt.title('Frequency of views')
# Out:
# Text(0.5, 1.0, 'Frequency of views')

# %%
plt.hist(df_sample['dislikes'])
plt.xlabel('dislikes')
plt.ylabel('Frequency')
plt.title('Frequency of dislikes')
# Out:
# Text(0.5, 1.0, 'Frequency of dislikes')

# %%
plt.boxplot(df_sample['views'], showmeans=True, meanline=True)
plt.ylabel('views count')
plt.title('Box Plot of views')
# Out:
# Text(0.5, 1.0, 'Box Plot of views')
